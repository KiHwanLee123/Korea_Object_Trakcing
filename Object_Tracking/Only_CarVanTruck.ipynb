# %%
# https://datasetninja.com/vehicle-dataset-for-yolo#introduction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck.zip') as target_file:
  target_file.extractall('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data')

# %%
# !cat /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 10
# names: ['Bus', 'Motorcyecle', 'Pickup', 'SUV', 'Sedan', 'Suv', 'TRUCK', 'TUCK', 'Truck', 'Van']
#
# roboflow:
#   workspace: cc-pintel
#   project: car-counting
#   version: 1
#   license: MIT
#   url: https://universe.roboflow.com/cc-pintel/car-counting/dataset/1

# %% [markdown]
# ---

# %%
import os
print('train : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/images")))
print('val : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images")))
print('test : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/test/images")))

print('train : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/labels")))
# Out:
# train :  5536
# val :  1456
# test :  291
# train :  5536

# %%
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels

# %%
import os
import shutil

# 파일이 있는 디렉토리와 이동할 디렉토리 설정
source_dir = "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/test/images"  # 파일이 있는 디렉토리
target_dir = "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images"   # 이동할 디렉토리

# 이동할 파일 개수 설정
num_files_to_move = len(os.listdir(source_dir))

# 소스 디렉토리에서 파일 리스트 가져오기
file_list = os.listdir(source_dir)

# 소스 디렉토리에서 이동할 파일 선택
files_to_move = file_list[:num_files_to_move]

# 파일 이동
for file_name in files_to_move:
    source_file_path = os.path.join(source_dir, file_name)
    target_file_path = os.path.join(target_dir, file_name)
    shutil.move(source_file_path, target_file_path)
    print(f"Moved '{file_name}' to '{target_dir}'")
# Out:
# Moved '-freemake_com-LOGO--DOH_14_mp4-14_jpg.rf.915b022b36d18d04ae2371ba2ef02727.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'
# Moved '-freemake_com-LOGO--DOH_14_mp4-3_jpg.rf.4f20134248e332c85695961bb093ca0f.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'
# Moved '113_jpg.rf.382b41681f9f5e6ce6c21876466c87cc.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'
# Moved '190_jpg.rf.a836f47fc26f7be5eba543ea7df3ea90.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'
# Moved '211---Copy_jpg.rf.36b9cd440d42f8b164198bced5766a7d.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'
# ...

# %%
import os
import shutil

# 파일이 있는 디렉토리와 이동할 디렉토리 설정
source_dir = "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/test/labels"  # 파일이 있는 디렉토리
target_dir = "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels"   # 이동할 디렉토리

# 이동할 파일 개수 설정
num_files_to_move = len(os.listdir(source_dir))

# 소스 디렉토리에서 파일 리스트 가져오기
file_list = os.listdir(source_dir)

# 소스 디렉토리에서 이동할 파일 선택
files_to_move = file_list[:num_files_to_move]

# 파일 이동
for file_name in files_to_move:
    source_file_path = os.path.join(source_dir, file_name)
    target_file_path = os.path.join(target_dir, file_name)
    shutil.move(source_file_path, target_file_path)
    print(f"Moved '{file_name}' to '{target_dir}'")
# Out:
# Moved '-freemake_com-LOGO--DOH_14_mp4-14_jpg.rf.915b022b36d18d04ae2371ba2ef02727.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels'
# Moved '-freemake_com-LOGO--DOH_14_mp4-3_jpg.rf.4f20134248e332c85695961bb093ca0f.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels'
# Moved '113_jpg.rf.382b41681f9f5e6ce6c21876466c87cc.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels'
# Moved '190_jpg.rf.a836f47fc26f7be5eba543ea7df3ea90.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels'
# Moved '211---Copy_jpg.rf.36b9cd440d42f8b164198bced5766a7d.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/labels'
# ...

# %%
import os
print('train : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/images")))
print('val : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images")))
print('test : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/test/images")))

print('train : ', len(os.listdir("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/labels")))
# Out:
# train :  5536
# val :  1747
# test :  0
# train :  5536

# %% [markdown]
# # YAML 파일 만들기

# %%
# !pip install PyYAML

# %%
import yaml

data = {'train' : "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/images",
        'val' : "/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images",
        'names' : ['Bus', 'Motorcyecle', 'Pickup', 'SUV', 'Sedan', 'Suv', 'TRUCK', 'TUCK', 'Truck', 'Van'],
        'nc' : 10 } # 대응시킬 것들과 개수

# 데이터 경로와 클래스 정보를 저장하고 있는 딕셔너리 객체 data를 YOLOv8 학습에 필요한 Underwater_Data.yaml 저장
with open("/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/CarVanTruck_Data.yaml", 'w') as f:
  yaml.dump(data, f)

# Underwater_Data.yaml 읽어서 화면에 출력
with open('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/CarVanTruck_Data.yaml', 'r') as f:
  underwater_yaml = yaml.safe_load(f)
  display(underwater_yaml)
# Out:
# {'names': ['Bus',
#   'Motorcyecle',
#   'Pickup',
#   'SUV',
#   'Sedan',
#   'Suv',
#   'TRUCK',
#   'TUCK',
#   'Truck',
#   'Van'],
#  'nc': 10,
#  'train': '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/images',
#  'val': '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/valid/images'}

# %% [markdown]
# # Install YOLOv8 & load

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.9/715.9 kB 10.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.17 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
from ultralytics import YOLO

# MS COCO 사전학습된 모델들 load : 8n,8s,8m,8l,8x,...
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 255MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %% [markdown]
# # YOLOv8 커스텀 데이터 학습하기

# %%
path = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/train/images'
lst = os.listdir(path)

from PIL import Image

img = os.path.join(path, lst[500])
Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>

# %%
import numpy as np
np_img = np.array(Image.open(img))
print(np_img.shape)
# Out:
# (416, 416, 3)

# %%
model.train(data='/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/CarVanTruck_Data.yaml', epochs=50,
            project='/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO',
            patience=5, batch=32, imgsz=416)
# Out:
# Ultralytics YOLOv8.1.17 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import torch
torch.save(model.state_dict(), '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/CarVanTruck_Data/model_weights.pt')

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 10
# {0: 'Bus', 1: 'Motorcyecle', 2: 'Pickup', 3: 'SUV', 4: 'Sedan', 5: 'Suv', 6: 'TRUCK', 7: 'TUCK', 8: 'Truck', 9: 'Van'}

# %% [markdown]
# # 학습된 YOLOv8 이용해서 test images 예측

# %%
results = model.predict(source='/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test.JPG', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test.JPG: 288x416 1 Sedan, 2 Trucks, 1 Van, 81.4ms
# Speed: 1.3ms preprocess, 81.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 416)
# Results saved to /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/train22

# %%
from PIL import Image
import os

img_path = '/content/runs/detect/train2'
lst = os.listdir(img_path)

image_path = os.path.join(img_path, lst[0])
image = Image.open(image_path)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x426>

# %%
results = model.predict(source='/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test2.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test2.jpg: 416x416 4 Pickups, 1 Sedan, 2 Suvs, 2 Trucks, 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 5.8ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/train23

# %%
img_path = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test2.jpg'
lst = os.listdir(img_path)

image_path = os.path.join(img_path, lst[0])
image = Image.open(image_path)
display(image)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-25-6e8543c49e49> in <cell line: 2>()
#       1 img_path = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test2.jpg'
# ----> 2 lst = os.listdir(img_path)
#       3
#       4 image_path = os.path.join(img_path, lst[0])
#       5 image = Image.open(image_path)
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/car_test2.jpg'
