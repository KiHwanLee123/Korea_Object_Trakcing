# %%
# !wget -o Underwater_Objects_v2i_yolov8.zip https://universe.roboflow.com/ds/5LGFwafhCH?key=QKUPcuCaJh

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection.zip') as target_file:
  target_file.extractall('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data')

# %%
# !cat /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 7
# names: ['bike', 'bus', 'car', 'person', 'suv', 'truck', 'van']
#
# roboflow:
#   workspace: aosman
#   project: vehicle-detection-dy4do
#   version: 7
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/aosman/vehicle-detection-dy4do/dataset/7

# %% [markdown]
# ---

# %%
import os
print('train : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/train/images')))
print('val : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images')))
print('test : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/images')))
# Out:
# train :  3513
# val :  200
# test :  192

# %%
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/Underwater_Data/test
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/Underwater_Data/test/images
# !mkdir /content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/Underwater_Data/test/labels

# %%
import os
import shutil

# 파일이 있는 디렉토리와 이동할 디렉토리 설정
source_dir = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/images'  # 파일이 있는 디렉토리
target_dir = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'   # 이동할 디렉토리

# 이동할 파일 개수 설정
num_files_to_move = len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/images'))

# 소스 디렉토리에서 파일 리스트 가져오기
file_list = os.listdir(source_dir)

# 소스 디렉토리에서 이동할 파일 선택
files_to_move = file_list[:num_files_to_move]

# 파일 이동
for file_name in files_to_move:
    source_file_path = os.path.join(source_dir, file_name)
    target_file_path = os.path.join(target_dir, file_name)
    shutil.move(source_file_path, target_file_path)
    print(f"Moved '{file_name}' to '{target_dir}'")
# Out:
# Moved 'akpinar_mp4-148_jpg.rf.9bcd452e16deb2cfeda8117f8454b5b2.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'
# Moved 'akpinar_mp4-150_jpg.rf.6d0182d91dd9aa1969446117f1a1251e.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'
# Moved 'akpinar_mp4-151_jpg.rf.59a0612bb86a64b012dc6a1ce5c8956d.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'
# Moved 'akpinar_mp4-152_jpg.rf.6b5ee4548b4e9ffc86cb2663a3524f78.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'
# Moved 'akpinar_mp4-154_jpg.rf.71d3f68f54fdd31765e718f7c44c9af9.jpg' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'
# ...

# %%
import os
import shutil

# 파일이 있는 디렉토리와 이동할 디렉토리 설정
source_dir = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/labels'  # 파일이 있는 디렉토리
target_dir = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'   # 이동할 디렉토리

# 이동할 파일 개수 설정
num_files_to_move = len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/labels'))

# 소스 디렉토리에서 파일 리스트 가져오기
file_list = os.listdir(source_dir)

# 소스 디렉토리에서 이동할 파일 선택
files_to_move = file_list[:num_files_to_move]

# 파일 이동
for file_name in files_to_move:
    source_file_path = os.path.join(source_dir, file_name)
    target_file_path = os.path.join(target_dir, file_name)
    shutil.move(source_file_path, target_file_path)
    print(f"Moved '{file_name}' to '{target_dir}'")
# Out:
# Moved 'akpinar_mp4-148_jpg.rf.9bcd452e16deb2cfeda8117f8454b5b2.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'
# Moved 'akpinar_mp4-150_jpg.rf.6d0182d91dd9aa1969446117f1a1251e.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'
# Moved 'akpinar_mp4-151_jpg.rf.59a0612bb86a64b012dc6a1ce5c8956d.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'
# Moved 'akpinar_mp4-152_jpg.rf.6b5ee4548b4e9ffc86cb2663a3524f78.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'
# Moved 'akpinar_mp4-154_jpg.rf.71d3f68f54fdd31765e718f7c44c9af9.txt' to '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/labels'
# ...

# %%
import os
print('train : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/train/images')))
print('val : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images')))
print('test : ', len(os.listdir('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/test/images')))
# Out:
# train :  3513
# val :  392
# test :  0

# %% [markdown]
# # YAML 파일 만들기

# %%
# !pip install PyYAML

# %%
import yaml

data = {'train' : '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/train/images',
        'val' : '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images',
        'names' : ['bike', 'bus', 'car', 'person', 'suv', 'truck', 'van'],
        'nc' : 7 } # 대응시킬 것들과 개수

# 데이터 경로와 클래스 정보를 저장하고 있는 딕셔너리 객체 data를 YOLOv8 학습에 필요한 Underwater_Data.yaml 저장
with open('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/VehicleDetection_Data.yaml', 'w') as f:
  yaml.dump(data, f)

# Underwater_Data.yaml 읽어서 화면에 출력
with open('/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/VehicleDetection_Data.yaml', 'r') as f:
  underwater_yaml = yaml.safe_load(f)
  display(underwater_yaml)
# Out:
# {'names': ['bike', 'bus', 'car', 'person', 'suv', 'truck', 'van'],
#  'nc': 7,
#  'train': '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/train/images',
#  'val': '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/valid/images'}

# %% [markdown]
# # Install YOLOv8 & load

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.1/715.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from ultralytics import YOLO

# MS COCO 사전학습된 모델들 load : 8n,8s,8m,8l,8x,...
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 149MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %% [markdown]
# # YOLOv8 커스텀 데이터 학습하기

# %%
path = '/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/train/images'
lst = os.listdir(path)

from PIL import Image

img = os.path.join(path, lst[3000])
Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
import numpy as np
np_img = np.array(Image.open(img))
print(np_img.shape)
# Out:
# (640, 640, 3)

# %%
model.train(data='/content/drive/MyDrive/KT_aivle/딥러닝/CNN/Object_Detection/YOLO/VehicleDetection_Data/VehicleDetection_Data.yaml', epochs=3, patience=3, batch=32, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 7
# {0: 'bike', 1: 'bus', 2: 'car', 3: 'person', 4: 'suv', 5: 'truck', 6: 'van'}

# %% [markdown]
# # 학습된 YOLOv8 이용해서 test images 예측

# %%
results = model.predict(source='/content/car_test.JPG', save=True)
# Out:
# image 1/1 /content/car_test.JPG: 448x640 8 cars, 2 trucks, 5 vans, 143.0ms
# Speed: 3.2ms preprocess, 143.0ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train2

# %%
from PIL import Image
import os

img_path = '/content/runs/detect/train2'
lst = os.listdir(img_path)

image_path = os.path.join(img_path, lst[0])
image = Image.open(image_path)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x426>
